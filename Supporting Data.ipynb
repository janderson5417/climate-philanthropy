# %% [markdown]
# Supporting data for my NYCDSA Python presentation; data taken from Forbes "Most Philanthropic Billionaires" (1/19/2021)

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
plt.style.use('ggplot')

# %%
phil_df = pd.read_csv('Top_Philanthropists.csv')

# %%
phil_df.head()
# Out:
#                          Name     Net Worth  Lifetime Giving  \
# 0      Charles "Chuck" Feeney  2.000000e+06     8.000000e+09
# 1            T. Denny Sanford  1.600000e+09     1.800000e+09
# 2                  Ted Turner  2.200000e+09     1.300000e+09
# 3       John and Laura Arnold  3.300000e+09     1.240000e+09
# 4  Lynn and Stacy Schusterman  3.400000e+09     1.840000e+09
#
#                                  Focus
# 0         Science, human rights, youth
# 1                Healthcare, education
# 2          United Nations, environment
# 3  Education, criminal justice, health
# 4             Education, Jewish causes

# %%
phil_df['Fra_Giving'] = (phil_df['Lifetime Giving']/phil_df['Net Worth'])/100

# %%
phil_df.head(26)
# Out:
#                                   Name     Net Worth  Lifetime Giving  \
# 0               Charles "Chuck" Feeney  2.000000e+06     8.000000e+09
# 1                     T. Denny Sanford  1.600000e+09     1.800000e+09
# 2                           Ted Turner  2.200000e+09     1.300000e+09
# 3                John and Laura Arnold  3.300000e+09     1.240000e+09
# 4           Lynn and Stacy Schusterman  3.400000e+09     1.840000e+09
# 5                  Amos Hostetter, Jr.  3.600000e+09     1.200000e+09
# 6                Julian Robertson, Jr.  4.300000e+09     1.300000e+09
# 7                        George Kaiser  5.400000e+09     1.300000e+09
# 8                 Eli and Edythe Broad  6.900000e+09     2.800000e+09
# 9                         George Soros  8.600000e+09     1.680000e+10
# 10              Gordon and Betty Moore  1.180000e+10     5.150000e+09
# 11                         Donald Bren  1.530000e+10     1.300000e+09
# ...

# %%
type(phil_df.loc[:, 'Name': 'Lifetime Giving'])
# Out:
# pandas.core.frame.DataFrame

# %%
plt.figure(figsize = (10,8))
plt.scatter(phil_df['Net Worth'], phil_df['Lifetime Giving'], 
            s=200, c='b', marker=None, cmap=None, norm=None, vmin=None, vmax=None, alpha=None, 
            linewidths=None, edgecolors=None, plotnonfinite=False, data=None)
plt.xlabel("Net Worth, $USD", fontsize = 15)
plt.ylabel("Lifetime Giving, $USD", fontsize = 15)
plt.title("Forbes, 25 Most Philanthropic Billionaires (1/19/2021)", fontsize = 18)

plt.show()

# %%
volume = (15 * price_data.volume[:-2] / price_data.volume[0])**2
close = 0.003 * price_data.close[:-2] / 0.003 * price_data.open[:-2]

fig, ax = plt.subplots()
ax.scatter(delta1[:-1], delta1[1:], c=close, s=volume, alpha=0.5)

ax.set_xlabel(r'$\Delta_i$', fontsize=15)
ax.set_ylabel(r'$\Delta_{i+1}$', fontsize=15)
ax.set_title('Volume and percent change')

ax.grid(True)
fig.tight_layout()

plt.show()
